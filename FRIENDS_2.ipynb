# %% [markdown]
# <a href="https://colab.research.google.com/github/k-avya/FRIENDS/blob/main/FRIENDS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-20c9220c-c3b1-4c92-ad45-c28a4c7239e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20c9220c-c3b1-4c92-ad45-c28a4c7239e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df1= pd.read_csv('friends_episodes_v3.csv', encoding='ISO-8859-1')

# %%
y = df1['Summary'].str.contains('Ross')
df1['Ross'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
y = df1['Summary'].str.contains('Monica')
df1['Monica'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
y = df1['Summary'].str.contains('Rachel')
df1['Rachel'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
y = df1['Summary'].str.contains('Phoebe')
df1['Phoebe'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
y = df1['Summary'].str.contains('Joey')
df1['Joey'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
y = df1['Summary'].str.contains('Chandler')
df1['Chandler'] = y
df1
# Out:
#      Year_of_prod  Season  Episode Number  \
# 0            1994       1               1
# 1            1994       1               2
# 2            1994       1               3
# 3            1994       1               4
# 4            1994       1               5
# ..            ...     ...             ...
# 231          2004      10              14
# 232          2004      10              15
# 233          2004      10              16
# 234          2004      10              17
# 235          2004      10              18
#
#                                        Episode_Title  Duration  \
# 0    The One Where Monica Gets a Roommate: The Pilot        22
# 1               The One with the Sonogram at the End        22
# 2                             The One with the Thumb        22
# 3                 The One with George Stephanopoulos        22
# 4     The One with the East German Laundry Detergent        22
# ..                                               ...       ...
# ...

# %%
import xlwt 
  
workbook = xlwt.Workbook()  
  
sheet = workbook.add_sheet("FRIENDS_2") 
  
# Specifying style 
style = xlwt.easyxf('font: bold 1') 
  
# Specifying column 
sheet.write(1170,3, 'SAMPLE', style) 
workbook.save("data_frames")

# %%
pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data= pd.DataFrame({'FRIENDS_2': ["Year_of_prod",	"Season",	"Episode Number","Episode_Title",	"Duration",	"Summary",	"Director",	"Stars",	"Votes",	"Ross",	"Monica",	"Rachel",	"Phoebe",	"Joey",	"Chandler"]})
datatoexcel= pd.ExcelWriter("frnds1.xlsx", engine='xlsxwriter')
data.to_excel(datatoexcel, sheet_name='Sheet1')
datatoexcel.save()

# %%
df=pd.DataFrame(df1,columns=["Year_of_prod",	"Season", "Episode Number"	"Episode_Title",	"Duration",	"Summary",	"Director",	"Stars",	"Votes",	"Ross",	"Monica",	"Rachel",	"Phoebe",	"Joey",	"Chandler"])
df.to_excel(r'C:\Users\kavya srivastava\Downloads\export_dataframe.xlsx',index=True)
