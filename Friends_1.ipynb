# %% [markdown]
# <a href="https://colab.research.google.com/github/k-avya/FRIENDS/blob/main/Friends_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-275e6a35-44de-4ffe-ba09-50a7d7e41d8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-275e6a35-44de-4ffe-ba09-50a7d7e41d8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df1=pd.read_csv('friends_episodes_v2.csv')

# %%
p = df1.head()
p
# Out:
#    Year_of_prod  Season                                   Episode_Title  \
# 0          1994       1            The One with the Sonogram at the End
# 1          1994       1                          The One with the Thumb
# 2          1994       1              The One with George Stephanopoulos
# 3          1994       1  The One with the East German Laundry Detergent
# 4          1994       1                           The One with the Butt
#
#    Duration                                            Summary  \
# 0        22  Ross finds out his ex-wife is pregnant. Rachel...
# 1        22  Monica becomes irritated when everyone likes h...
# 2        22  Joey and Chandler take Ross to a hockey game t...
# 3        22  Eager to spend time with Rachel, Ross pretends...
# 4        22  Monica's obsessiveness is put to the test afte...
#
#          Director  Stars  Votes
# 0   James Burrows    8.1   4888
# 1   James Burrows    8.2   4605
# 2   James Burrows    8.1   4468
# ...

# %%
if "Ross" in df1.Summary:
    df1.Ross = "Found"
else:
    df1.Ross = "Not Found"

df1.Ross
# Out:
# 'Not Found'

# %%
y = df1['Summary'].str.contains('Ross')
df1['Ross'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
y = df1['Summary'].str.contains('Monica')
df1['Monica'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
y = df1['Summary'].str.contains('Rachel')
df1['Rachel'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
y = df1['Summary'].str.contains('Phoebe')
df1['Phoebe'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
y = df1['Summary'].str.contains('Joey')
df1['Joey'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
y = df1['Summary'].str.contains('Chandler')
df1['Chandler'] = y
df1
# Out:
#      Year_of_prod  Season                                   Episode_Title  \
# 0            1994       1            The One with the Sonogram at the End
# 1            1994       1                          The One with the Thumb
# 2            1994       1              The One with George Stephanopoulos
# 3            1994       1  The One with the East German Laundry Detergent
# 4            1994       1                           The One with the Butt
# ..            ...     ...                                             ...
# 230          2004      10                  The One with Princess Consuela
# 231          2004      10                      The One Where Estelle Dies
# 232          2004      10          The One with Rachel's Going Away Party
# 233          2004      10                                    The Last One
# 234          2004      10                                    The Last One
#
#      Duration                                            Summary  \
# ...

# %%
import xlwt 
  
workbook = xlwt.Workbook()  
  
sheet = workbook.add_sheet("FRIENDS_1") 
  
# Specifying style 
style = xlwt.easyxf('font: bold 1') 
  
# Specifying column 
sheet.write(1170,3, 'SAMPLE', style) 
workbook.save("data_frames")

# %%
pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 149 kB 35.0 MB/s
# ...

# %%
data= pd.DataFrame({'FRIENDS_1': ["Year_of_prod",	"Season",	"Episode_Title",	"Duration",	"Summary",	"Director",	"Stars",	"Votes",	"Ross",	"Monica",	"Rachel",	"Phoebe",	"Joey",	"Chandler"]})
datatoexcel= pd.ExcelWriter("frnds1.xlsx", engine='xlsxwriter')
data.to_excel(datatoexcel, sheet_name='Sheet1')
datatoexcel.save()

# %%
df=pd.DataFrame(df1,columns=["Year_of_prod",	"Season",	"Episode_Title",	"Duration",	"Summary",	"Director",	"Stars",	"Votes",	"Ross",	"Monica",	"Rachel",	"Phoebe",	"Joey",	"Chandler"])
df.to_excel(r'C:\Users\kavya srivastava\Downloads\export_dataframe.xlsx',index=True)
